# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4o")
result = mpdel.invoke("Are u hearing me?")
# Out:
# Running cells with 'venv (Python 3.13.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/hashim/Documents/Coding/ITI/RAG-Course-ITI/venv/bin/python -m pip install ipykernel -U --force-reinstall'
